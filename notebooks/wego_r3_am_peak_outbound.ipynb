# %% [markdown]
# ## ROUTE 3 INBOUND 6-9 AM PEAK

# %%
import geopandas as gpd 
import requests 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import json
from shapely.geometry import LineString
import folium

# %matplotlib inline

# %%
with open('../data/WeGo.json')as start:
         credentials = json.load(start)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/3'

# %%
def concat_frames_columns(geo_response, response, date_range, time_range='6am-9am', days='m-f', in_or_out='inbound'):
    """This function pulls in two API requests, puts one in a geodataframe the other in a dataframe and concats desired columns"""
    geo_df = gpd.GeoDataFrame.from_features(geo_response.json()['features'])
    res_df = pd.DataFrame(response.json()['data']['segments'])
    full_df = pd.concat([geo_df, res_df[['countForSegment', 'percent20Secs']]], axis = 1)
    full_df['dates'] = date_range
    full_df['time'] = time_range
    full_df['days_of_week'] = days
    full_df['direction']= in_or_out
    full_df['max_seg_count'] = full_df['countForSegment'].max()
    full_df['proportion_of_segments'] = full_df['countForSegment']/full_df['max_seg_count']
    return full_df

# %% [markdown]
# ## In School Months - Jan to May

# %%
params1a = {
    'direction':'1',
    'startDate':'01-25-2022',
    'endDate': '02-24-2022',
    'excludeDates': '02-18-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params1b = {
    'direction':'1',
    'startDate':'01-25-2022',
    'endDate': '02-24-2022',
    'excludeDates': '02-18-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_jantofeb = concat_frames_columns(requests.get(URL, params = params1a, headers = headers), 
                                      requests.get(URL, params = params1b, headers = headers), "4/27/22-5/25/22")
mfam_jantofeb
# Out:
#                                               geometry fromStopId  \
# 0    LINESTRING (-86.83118 36.13237, -86.83094 36.1...   WESWILEF
# 1    LINESTRING (-86.84469 36.12699, -86.84448 36.1...   HARKENEN
# 2    LINESTRING (-86.85747 36.13943, -86.85748 36.1...   WHIKENSN
# 3    LINESTRING (-86.81407 36.14374, -86.81388 36.1...   WES31AEM
# 4    LINESTRING (-86.79801 36.15197, -86.79777 36.1...   WES20AEN
# ..                                                 ...        ...
# 467  LINESTRING (-86.79247 36.15442, -86.79222 36.1...   WES17AEN
# 468  LINESTRING (-86.84759 36.12496, -86.84738 36.1...   WHIPOSSN
# 469  LINESTRING (-86.82312 36.13552, -86.82291 36.1...   WESELMEN
# 470  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
# 471  LINESTRING (-86.78462 36.16286, -86.78474 36.1...   8AVUNINN
#
#                             fromStopName  toStopId  \
# 0     WESWILEF (stop name not available)  WESLEOEN
# 1           West End Ave & Kenner Ave Eb  HARWOOEN
# 2         White Bridge Pike & Kendall Sb  WHIKNOSN
# 3           West End Ave & 31st Ave S Eb  WES28AEM
# 4           West End Ave & 20th Ave S Eb  WES17AEN
# ..                                   ...       ...
# 467         West End Ave & 17th Ave S Eb  BRO12AEF
# 468       White Bridge Pike & Post Rd Sb  HARKENEN
# 469      West End Ave & Elmington Ave Eb  WES440EM
# 470  White Bridge Pike & Charlotte Shone  WHICORSF
# 471              8th Ave N & Union St Nb   CHA7AEN
#
#                             toStopName  pathLengthMeters  \
# 0       West End Ave  & Leonard Ave Eb            23.816
# 1        Harding Pike & Woodlawn Dr Eb            24.495
# 2       White Bridge Pike & Knob Dr Sb            23.616
# 3         West End Ave & 28th Ave S Eb            24.297
# 4         West End Ave & 17th Ave S Eb            24.723
# ..                                 ...               ...
# 467         Broadway Ave & 12th Ave Eb            24.692
# 468       West End Ave & Kenner Ave Eb            24.853
# 469       West End Ave & I-440 Ramp Eb            24.392
# 470  White Bridge Pike & Corbett Ln Sb            24.651
# 471       Charlotte Ave & 7th Ave N Eb            24.033
#
#      averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                1.596712           14.915652    2.518          1.907  ...
# 1                2.051801           11.938292    9.049          2.804  ...
# 2                1.818951           12.983307    5.271          2.301  ...
# 3                2.564372            9.474834   11.988          3.511  ...
# 4                3.192674            7.743666   18.146          6.418  ...
# ..                    ...                 ...      ...            ...  ...
# 467              1.994077           12.382671    4.157          2.430  ...
# 468              5.305432            4.684444   33.755          6.688  ...
# 469              2.123626           11.486015    3.478          2.809  ...
# 470              3.018139            8.167616    6.773          5.032  ...
# 471              5.934456            4.049739   33.227         12.046  ...
#
#      percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0            1.302    1.098              170          1.362  4/27/22-5/25/22
# 1            1.298    1.005              171          1.490  4/27/22-5/25/22
# 2            1.381    1.228              142          1.481  4/27/22-5/25/22
# 3            1.744    1.531              172          1.905  4/27/22-5/25/22
# 4            1.515    1.130              184          1.698  4/27/22-5/25/22
# ..             ...      ...              ...            ...              ...
# 467          1.552    1.266              182          1.702  4/27/22-5/25/22
# 468          3.278    2.833              169          3.719  4/27/22-5/25/22
# 469          1.578    1.270              171          1.737  4/27/22-5/25/22
# 470          1.670    1.282               79          1.946  4/27/22-5/25/22
# 471          2.165    1.727              171          2.360  4/27/22-5/25/22
#
#         time  days_of_week  direction max_seg_count proportion_of_segments
# 0    6am-9am           m-f    inbound           187               0.909091
# 1    6am-9am           m-f    inbound           187               0.914439
# 2    6am-9am           m-f    inbound           187               0.759358
# 3    6am-9am           m-f    inbound           187               0.919786
# 4    6am-9am           m-f    inbound           187               0.983957
# ..       ...           ...        ...           ...                    ...
# 467  6am-9am           m-f    inbound           187               0.973262
# 468  6am-9am           m-f    inbound           187               0.903743
# 469  6am-9am           m-f    inbound           187               0.914439
# 470  6am-9am           m-f    inbound           187               0.422460
# 471  6am-9am           m-f    inbound           187               0.914439
#
# [472 rows x 24 columns]

# %%
jantofeb = mfam_jantofeb[mfam_jantofeb['percent20Secs'] > np.quantile(mfam_jantofeb['percent20Secs'], .80)]

# %%
params2a = {
    'direction':'1',
    'startDate':'02-25-2022',
    'endDate': '03-26-2022',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params2b = {
    'direction':'1',
    'startDate':'02-25-2022',
    'endDate': '03-26-2022',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_febtomar = concat_frames_columns(requests.get(URL, params = params2a, headers = headers), 
                                      requests.get(URL, params = params2b, headers = headers), "4/27/22-5/25/22")
mfam_febtomar
# Out:
#                                               geometry fromStopId  \
# 0    LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 1                             GEOMETRYCOLLECTION EMPTY        NaN
# 2    LINESTRING (-86.84323 36.12786, -86.84300 36.1...   HARWOOEN
# 3    LINESTRING (-86.84469 36.12699, -86.84448 36.1...   HARKENEN
# 4    LINESTRING (-86.81388 36.14390, -86.81369 36.1...   WES31AEM
# ..                                                 ...        ...
# 556  LINESTRING (-86.82312 36.13552, -86.82291 36.1...   WESELMEN
# 557  LINESTRING (-86.83047 36.13264, -86.83022 36.1...   WESWILEN
# 558  LINESTRING (-86.83714 36.13047, -86.83690 36.1...   HARVINEN
# 559  LINESTRING (-86.78462 36.16286, -86.78474 36.1...   8AVUNINN
# 560  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
#
#                             fromStopName  toStopId  \
# 0       West End Ave & Acklen Park Dr Eb  WES31AEM
# 1                                    NaN       NaN
# 2          Harding Pike & Woodlawn Dr Eb  HARVINEN
# 3           West End Ave & Kenner Ave Eb  HARWOOEN
# 4           West End Ave & 31st Ave S Eb  WES28AEM
# ..                                   ...       ...
# 556      West End Ave & Elmington Ave Eb  WES440EM
# 557               West End & Wilson Blvd  WESLEOEN
# 558            Harding Pike & Vine Ct Eb  WESWILEN
# 559              8th Ave N & Union St Nb   CHA7AEN
# 560  White Bridge Pike & Charlotte Shone  WHICORSF
#
#                             toStopName  pathLengthMeters  \
# 0         West End Ave & 31st Ave S Eb            24.265
# 1                                  NaN            23.816
# 2            Harding Pike & Vine Ct Eb            24.851
# 3        Harding Pike & Woodlawn Dr Eb            24.495
# 4         West End Ave & 28th Ave S Eb            24.297
# ..                                 ...               ...
# 556       West End Ave & I-440 Ramp Eb            24.392
# 557     West End Ave  & Leonard Ave Eb            23.956
# 558             West End & Wilson Blvd            23.901
# 559       Charlotte Ave & 7th Ave N Eb            24.033
# 560  White Bridge Pike & Corbett Ln Sb            24.651
#
#      averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                3.249949            7.466271   20.360          6.140  ...
# 1                1.698782           14.019456    5.045          2.115  ...
# 2                2.123400           11.703400    7.599          2.859  ...
# 3                2.250463           10.884427    8.269          3.437  ...
# 4                2.597438            9.354218    5.812          3.699  ...
# ..                    ...                 ...      ...            ...  ...
# 556              2.496135            9.771907   35.715          2.786  ...
# 557              2.602400            9.205349   13.134          6.815  ...
# 558              1.722350           13.876970    3.108          2.313  ...
# 559              7.202232            3.336882   46.448         15.191  ...
# 560              2.861267            8.615414    6.510          5.028  ...
#
#      percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0            1.806    1.440               39          1.930  4/27/22-5/25/22
# 1            1.278    0.564               87          1.400  4/27/22-5/25/22
# 2            1.498    1.375               40          1.558  4/27/22-5/25/22
# 3            1.352    1.012              123          1.513  4/27/22-5/25/22
# 4            1.751    1.347               89          1.917  4/27/22-5/25/22
# ..             ...      ...              ...            ...              ...
# 556          1.627    1.215              126          1.773  4/27/22-5/25/22
# 557          1.298    1.167               40          1.382  4/27/22-5/25/22
# 558          1.332    1.165               40          1.424  4/27/22-5/25/22
# 559          2.287    1.970              125          2.608  4/27/22-5/25/22
# 560          1.434    0.854               45          1.578  4/27/22-5/25/22
#
#         time  days_of_week  direction max_seg_count proportion_of_segments
# 0    6am-9am           m-f    inbound           132               0.295455
# 1    6am-9am           m-f    inbound           132               0.659091
# 2    6am-9am           m-f    inbound           132               0.303030
# 3    6am-9am           m-f    inbound           132               0.931818
# 4    6am-9am           m-f    inbound           132               0.674242
# ..       ...           ...        ...           ...                    ...
# 556  6am-9am           m-f    inbound           132               0.954545
# 557  6am-9am           m-f    inbound           132               0.303030
# 558  6am-9am           m-f    inbound           132               0.303030
# 559  6am-9am           m-f    inbound           132               0.946970
# 560  6am-9am           m-f    inbound           132               0.340909
#
# [561 rows x 24 columns]

# %%
febtomar = mfam_febtomar[mfam_febtomar['percent20Secs'] > np.quantile(mfam_febtomar['percent20Secs'], .80)]

# %%
params3a = {
    'direction':'1',
    'startDate':'03-27-2022',
    'endDate': '04-26-2022',
    'excludeDates': '04-14-2022,04-15-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params3b = {
    'direction':'1',
    'startDate':'03-27-2022',
    'endDate': '04-26-2022',
    'excludeDates': '04-14-2022,04-15-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_martoapr = concat_frames_columns(requests.get(URL, params = params3a, headers = headers), 
                                      requests.get(URL, params = params3b, headers = headers), "4/27/22-5/25/22")
mfam_martoapr
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.92385 36.07396, -86.92358 36.0...   H70HICEN
# 1     LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 2     LINESTRING (-86.93141 36.07377, -86.93114 36.0...   H70COLEM
# 3     LINESTRING (-86.85175 36.12782, -86.85153 36.1...   WHIPOSSN
# 4     LINESTRING (-86.82550 36.13446, -86.82525 36.1...   WESLEOEN
# ...                                                 ...        ...
# 1047  LINESTRING (-86.87775 36.09626, -86.87751 36.0...   H70PEREN
# 1048  LINESTRING (-86.83047 36.13264, -86.83022 36.1...   WESWILEN
# 1049  LINESTRING (-86.83714 36.13047, -86.83690 36.1...   HARVINEN
# 1050  LINESTRING (-86.84734 36.12513, -86.84714 36.1...   HARWODEN
# 1051  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
#
#                              fromStopName  toStopId  \
# 0                  Hwy 70 S & Hicks Ln Eb  H70OLDEF
# 1        West End Ave & Acklen Park Dr Eb  WES31AEM
# 2          Hwy 70 S & Colice Jeanne Rd Eb  H70HICEN
# 3          White Bridge Pike & Post Rd Sb  HARKENEN
# 4          West End Ave  & Leonard Ave Eb  WESELMEN
# ...                                   ...       ...
# 1047      Hwy 70 S & Percy Warner Blvd Eb  HARHAREN
# 1048               West End & Wilson Blvd  WESLEOEN
# 1049            Harding Pike & Vine Ct Eb  WESWILEN
# 1050         Harding Pike & Woodmont Blvd  HARKENEN
# 1051  White Bridge Pike & Charlotte Shone  WHICORSF
#
#                              toStopName  pathLengthMeters  \
# 0        Hwy 70 S & Old Hickory Blvd Eb            24.305
# 1          West End Ave & 31st Ave S Eb            24.265
# 2                Hwy 70 S & Hicks Ln Eb            24.285
# 3          West End Ave & Kenner Ave Eb            24.853
# 4       West End Ave & Elmington Ave Eb            24.572
# ...                                 ...               ...
# 1047       Harding Pike & Harding Pl Eb            24.744
# 1048     West End Ave  & Leonard Ave Eb            23.956
# 1049             West End & Wilson Blvd            23.901
# 1050       West End Ave & Kenner Ave Eb            23.943
# 1051  White Bridge Pike & Corbett Ln Sb            24.651
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                 1.640527           14.815361    3.434          1.946  ...
# 1                 2.791865            8.691323   18.689          4.233  ...
# 2                 1.428369           17.001909    1.801          1.654  ...
# 3                 2.464059           10.086203    7.300          4.289  ...
# 4                 9.770418            2.514938   85.301         33.954  ...
# ...                    ...                 ...      ...            ...  ...
# 1047              1.675614           14.767124   23.502          1.665  ...
# 1048              1.950233           12.283660   21.228          2.290  ...
# 1049              1.693736           14.111408    3.975          2.185  ...
# 1050              2.690469            8.899192    4.757          3.987  ...
# 1051              3.096351            7.961307    6.641          5.727  ...
#
#       percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0             1.296    0.530              112          1.438  4/27/22-5/25/22
# 1             1.800    1.401              274          1.946  4/27/22-5/25/22
# 2             1.233    1.122              111          1.288  4/27/22-5/25/22
# 3             1.494    1.123              153          1.641  4/27/22-5/25/22
# 4             1.567    0.741              268          1.737  4/27/22-5/25/22
# ...             ...      ...              ...            ...              ...
# 1047          1.121    0.761              114          1.181  4/27/22-5/25/22
# 1048          1.301    0.644              266          1.391  4/27/22-5/25/22
# 1049          1.279    0.748              269          1.400  4/27/22-5/25/22
# 1050          1.798    1.018              113          1.925  4/27/22-5/25/22
# 1051          1.577    0.646               74          1.777  4/27/22-5/25/22
#
#          time  days_of_week  direction max_seg_count proportion_of_segments
# 0     6am-9am           m-f    inbound           278               0.402878
# 1     6am-9am           m-f    inbound           278               0.985612
# 2     6am-9am           m-f    inbound           278               0.399281
# 3     6am-9am           m-f    inbound           278               0.550360
# 4     6am-9am           m-f    inbound           278               0.964029
# ...       ...           ...        ...           ...                    ...
# 1047  6am-9am           m-f    inbound           278               0.410072
# 1048  6am-9am           m-f    inbound           278               0.956835
# 1049  6am-9am           m-f    inbound           278               0.967626
# 1050  6am-9am           m-f    inbound           278               0.406475
# 1051  6am-9am           m-f    inbound           278               0.266187
#
# [1052 rows x 24 columns]

# %%
martoapr = mfam_martoapr[mfam_martoapr['percent20Secs'] > np.quantile(mfam_martoapr['percent20Secs'], .80)]

# %%
params4a = {
    'direction': '1',
    'startDate': '04-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '05-25-2022',
    'endTime' : '09:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params4b = {
    'direction': '1',
    'startDate': '04-27-2022',
    'beginTime' : '06:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '05-25-2022',
    'endTime' : '09:00',
    'resolution': 'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_aprtomay = concat_frames_columns(requests.get(URL, params = params4a, headers = headers), 
                                      requests.get(URL, params = params4b, headers = headers), "4/27/22-5/25/22")
mfam_aprtomay
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.92385 36.07396, -86.92358 36.0...   H70HICEN
# 1     LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 2     LINESTRING (-86.93141 36.07377, -86.93114 36.0...   H70COLEM
# 3     LINESTRING (-86.85175 36.12782, -86.85153 36.1...   WHIPOSSN
# 4     LINESTRING (-86.82550 36.13446, -86.82525 36.1...   WESLEOEN
# ...                                                 ...        ...
# 1047  LINESTRING (-86.83046 36.13264, -86.83022 36.1...   WESWILEN
# 1048  LINESTRING (-86.83714 36.13047, -86.83689 36.1...   HARVINEN
# 1049  LINESTRING (-86.87775 36.09626, -86.87751 36.0...   H70PEREN
# 1050  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
# 1051  LINESTRING (-86.84734 36.12513, -86.84714 36.1...   HARWODEN
#
#                              fromStopName  toStopId  \
# 0                  Hwy 70 S & Hicks Ln Eb  H70OLDEF
# 1        West End Ave & Acklen Park Dr Eb  WES31AEM
# 2          Hwy 70 S & Colice Jeanne Rd Eb  H70HICEN
# 3          White Bridge Pike & Post Rd Sb  HARKENEN
# 4          West End Ave  & Leonard Ave Eb  WESELMEN
# ...                                   ...       ...
# 1047               West End & Wilson Blvd  WESLEOEN
# 1048            Harding Pike & Vine Ct Eb  WESWILEN
# 1049      Hwy 70 S & Percy Warner Blvd Eb  HARHAREN
# 1050  White Bridge Pike & Charlotte Shone  WHICORSF
# 1051         Harding Pike & Woodmont Blvd  HARKENEN
#
#                              toStopName  pathLengthMeters  \
# 0        Hwy 70 S & Old Hickory Blvd Eb            24.305
# 1          West End Ave & 31st Ave S Eb            24.265
# 2                Hwy 70 S & Hicks Ln Eb            24.285
# 3          West End Ave & Kenner Ave Eb            24.853
# 4       West End Ave & Elmington Ave Eb            24.572
# ...                                 ...               ...
# 1047     West End Ave  & Leonard Ave Eb            23.956
# 1048             West End & Wilson Blvd            23.901
# 1049       Harding Pike & Harding Pl Eb            24.744
# 1050  White Bridge Pike & Corbett Ln Sb            24.651
# 1051       West End Ave & Kenner Ave Eb            23.943
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                 1.757360           13.830405   19.382          2.118  ...
# 1                 2.586487            9.381451   10.217          4.110  ...
# 2                 1.409444           17.230199    2.660          1.567  ...
# 3                 2.505006            9.921334   10.602          4.182  ...
# 4                 8.374416            2.934175   81.765         33.336  ...
# ...                    ...                 ...      ...            ...  ...
# 1047              1.734355           13.812628   25.246          2.028  ...
# 1048              1.689211           14.149209    6.216          2.276  ...
# 1049              1.584044           15.620778   17.110          1.565  ...
# 1050              2.911820            8.465839    6.148          5.110  ...
# 1051              2.724392            8.788383    5.194          3.757  ...
#
#       percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0             1.305    1.077              161          1.381  4/27/22-5/25/22
# 1             1.699    1.466              314          1.890  4/27/22-5/25/22
# 2             1.231    0.767              160          1.278  4/27/22-5/25/22
# 3             1.415    0.798              155          1.679  4/27/22-5/25/22
# 4             1.491    0.471              315          1.624  4/27/22-5/25/22
# ...             ...      ...              ...            ...              ...
# 1047          1.282    0.997              310          1.349  4/27/22-5/25/22
# 1048          1.284    1.048              313          1.366  4/27/22-5/25/22
# 1049          1.106    1.004              160          1.148  4/27/22-5/25/22
# 1050          1.367    0.804               89          1.729  4/27/22-5/25/22
# 1051          1.872    0.969              158          2.069  4/27/22-5/25/22
#
#          time  days_of_week  direction max_seg_count proportion_of_segments
# 0     6am-9am           m-f    inbound           320               0.503125
# 1     6am-9am           m-f    inbound           320               0.981250
# 2     6am-9am           m-f    inbound           320               0.500000
# 3     6am-9am           m-f    inbound           320               0.484375
# 4     6am-9am           m-f    inbound           320               0.984375
# ...       ...           ...        ...           ...                    ...
# 1047  6am-9am           m-f    inbound           320               0.968750
# 1048  6am-9am           m-f    inbound           320               0.978125
# 1049  6am-9am           m-f    inbound           320               0.500000
# 1050  6am-9am           m-f    inbound           320               0.278125
# 1051  6am-9am           m-f    inbound           320               0.493750
#
# [1052 rows x 24 columns]

# %%
aprtomay = mfam_aprtomay[mfam_aprtomay['percent20Secs'] > np.quantile(mfam_aprtomay['percent20Secs'], .80)]

# %% [markdown]
# ## Summer Months

# %%
params5a = {
    'direction':'1',
    'startDate':'05-26-2022',
    'endDate': '06-25-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params5b = {
    'direction':'1',
    'startDate':'05-26-2022',
    'endDate': '06-25-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_maytojun = concat_frames_columns(requests.get(URL, params = params5a, headers = headers), 
                                      requests.get(URL, params = params5b, headers = headers), "4/27/22-5/25/22")
mfam_maytojun
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.92385 36.07396, -86.92358 36.0...   H70HICEN
# 1     LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 2     LINESTRING (-86.93141 36.07377, -86.93114 36.0...   H70COLEM
# 3     LINESTRING (-86.85175 36.12782, -86.85153 36.1...   WHIPOSSN
# 4     LINESTRING (-86.82550 36.13446, -86.82525 36.1...   WESLEOEN
# ...                                                 ...        ...
# 1048  LINESTRING (-86.83046 36.13264, -86.83022 36.1...   WESWILEN
# 1049  LINESTRING (-86.83714 36.13047, -86.83689 36.1...   HARVINEN
# 1050  LINESTRING (-86.87775 36.09626, -86.87751 36.0...   H70PEREN
# 1051  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
# 1052  LINESTRING (-86.84734 36.12513, -86.84714 36.1...   HARWODEN
#
#                              fromStopName  toStopId  \
# 0                  Hwy 70 S & Hicks Ln Eb  H70OLDEF
# 1        West End Ave & Acklen Park Dr Eb  WES31AEM
# 2          Hwy 70 S & Colice Jeanne Rd Eb  H70HICEN
# 3          White Bridge Pike & Post Rd Sb  HARKENEN
# 4          West End Ave  & Leonard Ave Eb  WESELMEN
# ...                                   ...       ...
# 1048               West End & Wilson Blvd  WESLEOEN
# 1049            Harding Pike & Vine Ct Eb  WESWILEN
# 1050      Hwy 70 S & Percy Warner Blvd Eb  HARHAREN
# 1051  White Bridge Pike & Charlotte Shone  WHICORSF
# 1052         Harding Pike & Woodmont Blvd  HARKENEN
#
#                              toStopName  pathLengthMeters  \
# 0        Hwy 70 S & Old Hickory Blvd Eb            24.305
# 1          West End Ave & 31st Ave S Eb            24.265
# 2                Hwy 70 S & Hicks Ln Eb            24.285
# 3          West End Ave & Kenner Ave Eb            24.853
# 4       West End Ave & Elmington Ave Eb            24.572
# ...                                 ...               ...
# 1048     West End Ave  & Leonard Ave Eb            23.956
# 1049             West End & Wilson Blvd            23.901
# 1050       Harding Pike & Harding Pl Eb            24.744
# 1051  White Bridge Pike & Corbett Ln Sb            24.651
# 1052       West End Ave & Kenner Ave Eb            23.943
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                 1.601784           15.173706    2.809          1.945  ...
# 1                 2.621083            9.257624   30.426          3.815  ...
# 2                 1.395699           17.399883    1.875          1.584  ...
# 3                 2.380140           10.441823    7.827          4.193  ...
# 4                 8.607729            2.854644   76.700         36.398  ...
# ...                    ...                 ...      ...            ...  ...
# 1048              1.687951           14.192355    5.787          2.190  ...
# 1049              1.653609           14.453840    8.603          2.040  ...
# 1050              1.425602           17.356878   13.784          1.609  ...
# 1051              2.966126            8.310840   22.776          5.556  ...
# 1052              3.334335            7.180742   83.472          4.191  ...
#
#       percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0             1.322    1.125              167          1.387  4/27/22-5/25/22
# 1             1.682    0.962              337          1.828  4/27/22-5/25/22
# 2             1.212    1.083              166          1.270  4/27/22-5/25/22
# 3             1.380    0.978              171          1.553  4/27/22-5/25/22
# 4             1.428    0.755              329          1.629  4/27/22-5/25/22
# ...             ...      ...              ...            ...              ...
# 1048          1.273    1.020              329          1.349  4/27/22-5/25/22
# 1049          1.285    0.829              335          1.358  4/27/22-5/25/22
# 1050          1.079    0.823              171          1.137  4/27/22-5/25/22
# 1051          0.792    0.388               95          1.411  4/27/22-5/25/22
# 1052          1.693    1.214              164          1.894  4/27/22-5/25/22
#
#          time  days_of_week  direction max_seg_count proportion_of_segments
# 0     6am-9am           m-f    inbound           347               0.481268
# 1     6am-9am           m-f    inbound           347               0.971182
# 2     6am-9am           m-f    inbound           347               0.478386
# 3     6am-9am           m-f    inbound           347               0.492795
# 4     6am-9am           m-f    inbound           347               0.948127
# ...       ...           ...        ...           ...                    ...
# 1048  6am-9am           m-f    inbound           347               0.948127
# 1049  6am-9am           m-f    inbound           347               0.965418
# 1050  6am-9am           m-f    inbound           347               0.492795
# 1051  6am-9am           m-f    inbound           347               0.273775
# 1052  6am-9am           m-f    inbound           347               0.472622
#
# [1053 rows x 24 columns]

# %%
maytojun = mfam_maytojun[mfam_maytojun['percent20Secs'] > np.quantile(mfam_maytojun['percent20Secs'], .80)]

# %%
params6a = {
    'direction':'1',
    'startDate':'06-26-2022',
    'endDate': '07-26-2022',
    'excludeDate': '07/04/2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params6b = {
    'direction':'1',
    'startDate':'06-26-2022',
    'endDate': '07-26-2022',
    'excludeDate': '07/04/2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_juntojul = concat_frames_columns(requests.get(URL, params = params6a, headers = headers), 
                                      requests.get(URL, params = params6b, headers = headers), "4/27/22-5/25/22")
mfam_juntojul
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.92385 36.07396, -86.92358 36.0...   H70HICEN
# 1     LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 2     LINESTRING (-86.93141 36.07377, -86.93114 36.0...   H70COLEM
# 3     LINESTRING (-86.85175 36.12782, -86.85153 36.1...   WHIPOSSN
# 4     LINESTRING (-86.82550 36.13446, -86.82525 36.1...   WESLEOEN
# ...                                                 ...        ...
# 1047  LINESTRING (-86.87775 36.09626, -86.87751 36.0...   H70PEREN
# 1048  LINESTRING (-86.83046 36.13264, -86.83022 36.1...   WESWILEN
# 1049  LINESTRING (-86.83714 36.13047, -86.83689 36.1...   HARVINEN
# 1050  LINESTRING (-86.84734 36.12513, -86.84714 36.1...   HARWODEN
# 1051  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
#
#                              fromStopName  toStopId  \
# 0                  Hwy 70 S & Hicks Ln Eb  H70OLDEF
# 1        West End Ave & Acklen Park Dr Eb  WES31AEM
# 2          Hwy 70 S & Colice Jeanne Rd Eb  H70HICEN
# 3          White Bridge Pike & Post Rd Sb  HARKENEN
# 4          West End Ave  & Leonard Ave Eb  WESELMEN
# ...                                   ...       ...
# 1047      Hwy 70 S & Percy Warner Blvd Eb  HARHAREN
# 1048               West End & Wilson Blvd  WESLEOEN
# 1049            Harding Pike & Vine Ct Eb  WESWILEN
# 1050         Harding Pike & Woodmont Blvd  HARKENEN
# 1051  White Bridge Pike & Charlotte Shone  WHICORSF
#
#                              toStopName  pathLengthMeters  \
# 0        Hwy 70 S & Old Hickory Blvd Eb            24.305
# 1          West End Ave & 31st Ave S Eb            24.265
# 2                Hwy 70 S & Hicks Ln Eb            24.285
# 3          West End Ave & Kenner Ave Eb            24.853
# 4       West End Ave & Elmington Ave Eb            24.572
# ...                                 ...               ...
# 1047       Harding Pike & Harding Pl Eb            24.744
# 1048     West End Ave  & Leonard Ave Eb            23.956
# 1049             West End & Wilson Blvd            23.901
# 1050       West End Ave & Kenner Ave Eb            23.943
# 1051  White Bridge Pike & Corbett Ln Sb            24.651
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                 1.579181           15.390889    3.634          1.907  ...
# 1                 2.579047            9.408514   17.390          3.979  ...
# 2                 1.446386           16.790124    3.532          1.632  ...
# 3                 2.162376           11.493376    5.366          3.779  ...
# 4                 6.948899            3.536100   76.658         23.171  ...
# ...                    ...                 ...      ...            ...  ...
# 1047              2.845957            8.694439  140.224          1.564  ...
# 1048              1.598453           14.986991    4.523          1.874  ...
# 1049              1.598844           14.948926    3.695          2.066  ...
# 1050              2.704179            8.854074   10.490          3.929  ...
# 1051              2.799278            8.806199   19.285          5.150  ...
#
#       percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0             1.294    0.777              160          1.389  4/27/22-5/25/22
# 1             1.658    1.318              317          1.785  4/27/22-5/25/22
# 2             1.228    1.144              158          1.290  4/27/22-5/25/22
# 3             1.341    1.033              165          1.443  4/27/22-5/25/22
# 4             1.452    0.734              318          1.552  4/27/22-5/25/22
# ...             ...      ...              ...            ...              ...
# 1047          1.107    0.777              162          1.147  4/27/22-5/25/22
# 1048          1.267    0.965              318          1.335  4/27/22-5/25/22
# 1049          1.240    0.962              321          1.329  4/27/22-5/25/22
# 1050          1.637    1.259              162          1.816  4/27/22-5/25/22
# 1051          0.808    0.630              115          1.462  4/27/22-5/25/22
#
#          time  days_of_week  direction max_seg_count proportion_of_segments
# 0     6am-9am           m-f    inbound           327               0.489297
# 1     6am-9am           m-f    inbound           327               0.969419
# 2     6am-9am           m-f    inbound           327               0.483180
# 3     6am-9am           m-f    inbound           327               0.504587
# 4     6am-9am           m-f    inbound           327               0.972477
# ...       ...           ...        ...           ...                    ...
# 1047  6am-9am           m-f    inbound           327               0.495413
# 1048  6am-9am           m-f    inbound           327               0.972477
# 1049  6am-9am           m-f    inbound           327               0.981651
# 1050  6am-9am           m-f    inbound           327               0.495413
# 1051  6am-9am           m-f    inbound           327               0.351682
#
# [1052 rows x 24 columns]

# %%
juntojul = mfam_juntojul[mfam_juntojul['percent20Secs'] > np.quantile(mfam_juntojul['percent20Secs'], .80)]

# %%
school = pd.concat([jantofeb, febtomar, martoapr, aprtomay], keys=['jantofeb','febtomar','martoapr','aprtomay'])
summer = pd.concat([maytojun, juntojul], keys = ['maytojun', 'juntojul'])
r3amschool = school['geometry'].to_json()
r3amsummer = summer['geometry'].to_json()
mapdawg = folium.Map(location = [36.19, -86.7775], zoom_start = 12)

# %%
style1 = {'color' : 'red', 'weight' : 6}
style2 = {'color' : 'blue', 'weight' : 3}
folium.GeoJson(r3amschool, style_function =lambda x:style1).add_to(mapdawg)
folium.GeoJson(r3amsummer, style_function = lambda x:style2).add_to(mapdawg)
mapdawg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d5b077d8616942c735f00fd05ef64b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d5b077d8616942c735f00fd05ef64b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5d5b077d8616942c735f00fd05ef64b9 = L.map(
#                 &quot;map_5d5b077d8616942c735f00fd05ef64b9&quot;,
#                 {
#                     center: [36.19, -86.7775],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2e551800eaa718a2c41b5bd686f220d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5d5b077d8616942c735f00fd05ef64b9);
#
#
#         function geo_json_c4a83a08035690447a72dd45c6d07ff9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;weight&quot;: 6};
#             }
#         }
#         function geo_json_c4a83a08035690447a72dd45c6d07ff9_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_5d5b077d8616942c735f00fd05ef64b9.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_c4a83a08035690447a72dd45c6d07ff9 = L.geoJson(null, {
#                 onEachFeature: geo_json_c4a83a08035690447a72dd45c6d07ff9_onEachFeature,
#
#                 style: geo_json_c4a83a08035690447a72dd45c6d07ff9_styler,
#         }).addTo(map_5d5b077d8616942c735f00fd05ef64b9);
#
#         function geo_json_c4a83a08035690447a72dd45c6d07ff9_add (data) {
#             geo_json_c4a83a08035690447a72dd45c6d07ff9.addData(data);
#         }
#             geo_json_c4a83a08035690447a72dd45c6d07ff9_add({&quot;bbox&quot;: [-86.95652569442052, 36.06878977378065, -86.7811952078171, 36.166452036677725], &quot;features&quot;: [{&quot;bbox&quot;: [-86.8082827653225, 36.146979496502624, -86.808055530645, 36.147088993005255], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.8082827653225, 36.146979496502624], [-86.808055530645, 36.147088993005255]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 7)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.818143670491, 36.14022132988891, -86.81795808926704, 36.14038847589194], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.818143670491, 36.14022132988891], [-86.81795808926704, 36.14038847589194]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 10)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78372914832912, 36.165036514168456, -86.78349553110549, 36.1651353522246], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78372914832912, 36.165036514168456], [-86.78349553110549, 36.1651353522246]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 12)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.808055530645, 36.147088993005255, -86.80782829596752, 36.14719848950788], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.808055530645, 36.147088993005255], [-86.80782829596752, 36.14719848950788]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 26)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78396276555274, 36.1649376761123, -86.78372914832912, 36.165036514168456], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78396276555274, 36.1649376761123], [-86.78372914832912, 36.165036514168456]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 27)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.81795808926704, 36.14038847589194, -86.81777250804308, 36.14055562189497], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.81795808926704, 36.14038847589194], [-86.81777250804308, 36.14055562189497]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 28)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78467356100748, 36.16463814721506, -86.78443584317608, 36.16473755649], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78467356100748, 36.16463814721506], [-86.78443584317608, 36.16473755649]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 44)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78326191388186, 36.165234190280756, -86.78302829665823, 36.1653330283369], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78326191388186, 36.165234190280756], [-86.78302829665823, 36.1653330283369]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&qu
