# %% [markdown]
# ## ROUTE 3 INBOUND 6-9 AM PEAK

# %%
import geopandas as gpd 
import requests 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import json
from shapely.geometry import LineString
import folium

# %matplotlib inline

# %%
with open('../data/WeGo.json')as start:
         credentials = json.load(start)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/3'

# %%
def concat_frames_columns(geo_response, response, date_range, time_range='6am-9am', days='m-f', in_or_out='inbound'):
    """This function pulls in two API requests, puts one in a geodataframe the other in a dataframe and concats desired columns"""
    geo_df = gpd.GeoDataFrame.from_features(geo_response.json()['features'])
    res_df = pd.DataFrame(response.json()['data']['segments'])
    full_df = pd.concat([geo_df, res_df[['countForSegment', 'percent20Secs']]], axis = 1)
    full_df['dates'] = date_range
    full_df['time'] = time_range
    full_df['days_of_week'] = days
    full_df['direction']= in_or_out
    full_df['max_seg_count'] = full_df['countForSegment'].max()
    full_df['proportion_of_segments'] = full_df['countForSegment']/full_df['max_seg_count']
    return full_df

# %% [markdown]
# ## In School Months - Jan to May

# %%
params1a = {
    'direction':'1',
    'startDate':'01-25-2022',
    'endDate': '02-24-2022',
    'excludeDates': '02-18-2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params1b = {
    'direction':'1',
    'startDate':'01-25-2022',
    'endDate': '02-24-2022',
    'excludeDates': '02-18-2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_jantofeb = concat_frames_columns(requests.get(URL, params = params1a, headers = headers), 
                                      requests.get(URL, params = params1b, headers = headers), "4/27/22-5/25/22")
mfam_jantofeb
# Out:
#                                               geometry fromStopId  \
# 0    LINESTRING (-86.83118 36.13237, -86.83094 36.1...   WESWILEF
# 1    LINESTRING (-86.84469 36.12699, -86.84448 36.1...   HARKENEN
# 2    LINESTRING (-86.81407 36.14374, -86.81388 36.1...   WES31AEM
# 3    LINESTRING (-86.85747 36.13943, -86.85748 36.1...   WHIKENSN
# 4    LINESTRING (-86.79801 36.15197, -86.79777 36.1...   WES20AEN
# ..                                                 ...        ...
# 466  LINESTRING (-86.79247 36.15442, -86.79222 36.1...   WES17AEN
# 467  LINESTRING (-86.84759 36.12496, -86.84738 36.1...   WHIPOSSN
# 468  LINESTRING (-86.82312 36.13552, -86.82291 36.1...   WESELMEN
# 469  LINESTRING (-86.78462 36.16286, -86.78474 36.1...   8AVUNINN
# 470  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
#
#                             fromStopName  toStopId  \
# 0     WESWILEF (stop name not available)  WESLEOEN
# 1           West End Ave & Kenner Ave Eb  HARWOOEN
# 2           West End Ave & 31st Ave S Eb  WES28AEM
# 3         White Bridge Pike & Kendall Sb  WHIKNOSN
# 4           West End Ave & 20th Ave S Eb  WES17AEN
# ..                                   ...       ...
# 466         West End Ave & 17th Ave S Eb  BRO12AEF
# 467       White Bridge Pike & Post Rd Sb  HARKENEN
# 468      West End Ave & Elmington Ave Eb  WES440EM
# 469              8th Ave N & Union St Nb   CHA7AEN
# 470  White Bridge Pike & Charlotte Shone  WHICORSF
#
#                             toStopName  pathLengthMeters  \
# 0       West End Ave  & Leonard Ave Eb            23.816
# 1        Harding Pike & Woodlawn Dr Eb            24.495
# 2         West End Ave & 28th Ave S Eb            24.297
# 3       White Bridge Pike & Knob Dr Sb            23.616
# 4         West End Ave & 17th Ave S Eb            24.723
# ..                                 ...               ...
# 466         Broadway Ave & 12th Ave Eb            24.692
# 467       West End Ave & Kenner Ave Eb            24.853
# 468       West End Ave & I-440 Ramp Eb            24.392
# 469       Charlotte Ave & 7th Ave N Eb            24.033
# 470  White Bridge Pike & Corbett Ln Sb            24.651
#
#      averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                1.466908           16.235510    2.220          1.730  ...
# 1                2.035048           12.036571    4.695          3.805  ...
# 2                2.441453            9.951861    4.623          3.717  ...
# 3                1.733855           13.620516    5.792          2.148  ...
# 4                1.974184           12.523149    3.925          2.551  ...
# ..                    ...                 ...      ...            ...  ...
# 466              2.132909           11.576678    3.273          3.107  ...
# 467              4.567218            5.441606   11.728          6.436  ...
# 468              1.773313           13.755045    3.141          2.378  ...
# 469              4.246302            5.659748    8.666          6.927  ...
# 470              3.253414            7.576964    7.529          5.515  ...
#
#      percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0            1.164    1.007               65          1.280  4/27/22-5/25/22
# 1            1.157    0.971               62          1.271  4/27/22-5/25/22
# 2            1.663    1.399               64          1.759  4/27/22-5/25/22
# 3            1.230    1.129               55          1.414  4/27/22-5/25/22
# 4            1.500    1.168               49          1.622  4/27/22-5/25/22
# ..             ...      ...              ...            ...              ...
# 466          1.683    1.646               44          1.735  4/27/22-5/25/22
# 467          2.398    2.009               55          2.851  4/27/22-5/25/22
# 468          1.272    1.074               64          1.434  4/27/22-5/25/22
# 469          3.043    2.720               43          3.128  4/27/22-5/25/22
# 470          1.812    1.339               58          1.912  4/27/22-5/25/22
#
#         time  days_of_week  direction max_seg_count proportion_of_segments
# 0    6am-9am           m-f    inbound            72               0.902778
# 1    6am-9am           m-f    inbound            72               0.861111
# 2    6am-9am           m-f    inbound            72               0.888889
# 3    6am-9am           m-f    inbound            72               0.763889
# 4    6am-9am           m-f    inbound            72               0.680556
# ..       ...           ...        ...           ...                    ...
# 466  6am-9am           m-f    inbound            72               0.611111
# 467  6am-9am           m-f    inbound            72               0.763889
# 468  6am-9am           m-f    inbound            72               0.888889
# 469  6am-9am           m-f    inbound            72               0.597222
# 470  6am-9am           m-f    inbound            72               0.805556
#
# [471 rows x 24 columns]

# %%
jantofeb = mfam_jantofeb[mfam_jantofeb['percent20Secs'] > np.quantile(mfam_jantofeb['percent20Secs'], .80)]

# %%
params2a = {
    'direction':'1',
    'startDate':'02-25-2022',
    'endDate': '03-26-2022',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params2b = {
    'direction':'1',
    'startDate':'02-25-2022',
    'endDate': '03-26-2022',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_febtomar = concat_frames_columns(requests.get(URL, params = params2a, headers = headers), 
                                      requests.get(URL, params = params2b, headers = headers), "4/27/22-5/25/22")
mfam_febtomar
# Out:
#                                               geometry fromStopId  \
# 0    LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 1                             GEOMETRYCOLLECTION EMPTY        NaN
# 2    LINESTRING (-86.84323 36.12786, -86.84300 36.1...   HARWOOEN
# 3    LINESTRING (-86.84469 36.12699, -86.84448 36.1...   HARKENEN
# 4    LINESTRING (-86.81388 36.14390, -86.81369 36.1...   WES31AEM
# ..                                                 ...        ...
# 556  LINESTRING (-86.82312 36.13552, -86.82291 36.1...   WESELMEN
# 557  LINESTRING (-86.83047 36.13264, -86.83022 36.1...   WESWILEN
# 558  LINESTRING (-86.83714 36.13047, -86.83690 36.1...   HARVINEN
# 559  LINESTRING (-86.78462 36.16286, -86.78474 36.1...   8AVUNINN
# 560  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
#
#                             fromStopName  toStopId  \
# 0       West End Ave & Acklen Park Dr Eb  WES31AEM
# 1                                    NaN       NaN
# 2          Harding Pike & Woodlawn Dr Eb  HARVINEN
# 3           West End Ave & Kenner Ave Eb  HARWOOEN
# 4           West End Ave & 31st Ave S Eb  WES28AEM
# ..                                   ...       ...
# 556      West End Ave & Elmington Ave Eb  WES440EM
# 557               West End & Wilson Blvd  WESLEOEN
# 558            Harding Pike & Vine Ct Eb  WESWILEN
# 559              8th Ave N & Union St Nb   CHA7AEN
# 560  White Bridge Pike & Charlotte Shone  WHICORSF
#
#                             toStopName  pathLengthMeters  \
# 0         West End Ave & 31st Ave S Eb            24.265
# 1                                  NaN            23.816
# 2            Harding Pike & Vine Ct Eb            24.851
# 3        Harding Pike & Woodlawn Dr Eb            24.495
# 4         West End Ave & 28th Ave S Eb            24.297
# ..                                 ...               ...
# 556       West End Ave & I-440 Ramp Eb            24.392
# 557     West End Ave  & Leonard Ave Eb            23.956
# 558             West End & Wilson Blvd            23.901
# 559       Charlotte Ave & 7th Ave N Eb            24.033
# 560  White Bridge Pike & Corbett Ln Sb            24.651
#
#      averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                2.235000           10.856823    4.214          3.578  ...
# 1                1.495576           15.924299    2.327          1.888  ...
# 2                1.545714           16.077360    1.848          1.805  ...
# 3                1.855319           13.202581    5.033          2.989  ...
# 4                2.372233           10.242249    3.961          2.979  ...
# ..                    ...                 ...      ...            ...  ...
# 556              1.696729           14.375896    2.687          2.284  ...
# 557              1.384286           17.305672    1.726          1.715  ...
# 558              1.372643           17.412393    1.649          1.585  ...
# 559              4.291000            5.600792    8.694          7.334  ...
# 560              3.102306            7.946025    6.639          5.444  ...
#
#      percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0            1.606    1.581               15          1.672  4/27/22-5/25/22
# 1            1.150    0.979               33          1.280  4/27/22-5/25/22
# 2            1.332    1.315               14          1.380  4/27/22-5/25/22
# 3            1.125    1.027               47          1.180  4/27/22-5/25/22
# 4            1.748    1.469               30          1.940  4/27/22-5/25/22
# ..             ...      ...              ...            ...              ...
# 556          1.254    1.112               48          1.440  4/27/22-5/25/22
# 557          1.158    1.134               14          1.202  4/27/22-5/25/22
# 558          1.153    1.136               14          1.174  4/27/22-5/25/22
# 559          3.033    2.696               32          3.077  4/27/22-5/25/22
# 560          1.806    1.413               49          2.001  4/27/22-5/25/22
#
#         time  days_of_week  direction max_seg_count proportion_of_segments
# 0    6am-9am           m-f    inbound            59               0.254237
# 1    6am-9am           m-f    inbound            59               0.559322
# 2    6am-9am           m-f    inbound            59               0.237288
# 3    6am-9am           m-f    inbound            59               0.796610
# 4    6am-9am           m-f    inbound            59               0.508475
# ..       ...           ...        ...           ...                    ...
# 556  6am-9am           m-f    inbound            59               0.813559
# 557  6am-9am           m-f    inbound            59               0.237288
# 558  6am-9am           m-f    inbound            59               0.237288
# 559  6am-9am           m-f    inbound            59               0.542373
# 560  6am-9am           m-f    inbound            59               0.830508
#
# [561 rows x 24 columns]

# %%
febtomar = mfam_febtomar[mfam_febtomar['percent20Secs'] > np.quantile(mfam_febtomar['percent20Secs'], .80)]

# %%
params3a = {
    'direction':'1',
    'startDate':'03-27-2022',
    'endDate': '04-26-2022',
    'excludeDates': '04-14-2022,04-15-2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params3b = {
    'direction':'1',
    'startDate':'03-27-2022',
    'endDate': '04-26-2022',
    'excludeDates': '04-14-2022,04-15-2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_martoapr = concat_frames_columns(requests.get(URL, params = params3a, headers = headers), 
                                      requests.get(URL, params = params3b, headers = headers), "4/27/22-5/25/22")
mfam_martoapr
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.92385 36.07396, -86.92358 36.0...   H70HICEN
# 1     LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 2     LINESTRING (-86.93141 36.07377, -86.93114 36.0...   H70COLEM
# 3     LINESTRING (-86.85175 36.12782, -86.85153 36.1...   WHIPOSSN
# 4     LINESTRING (-86.82550 36.13446, -86.82525 36.1...   WESLEOEN
# ...                                                 ...        ...
# 1046  LINESTRING (-86.87775 36.09626, -86.87751 36.0...   H70PEREN
# 1047  LINESTRING (-86.83047 36.13264, -86.83022 36.1...   WESWILEN
# 1048  LINESTRING (-86.83714 36.13047, -86.83690 36.1...   HARVINEN
# 1049  LINESTRING (-86.84734 36.12513, -86.84714 36.1...   HARWODEN
# 1050  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
#
#                              fromStopName  toStopId  \
# 0                  Hwy 70 S & Hicks Ln Eb  H70OLDEF
# 1        West End Ave & Acklen Park Dr Eb  WES31AEM
# 2          Hwy 70 S & Colice Jeanne Rd Eb  H70HICEN
# 3          White Bridge Pike & Post Rd Sb  HARKENEN
# 4          West End Ave  & Leonard Ave Eb  WESELMEN
# ...                                   ...       ...
# 1046      Hwy 70 S & Percy Warner Blvd Eb  HARHAREN
# 1047               West End & Wilson Blvd  WESLEOEN
# 1048            Harding Pike & Vine Ct Eb  WESWILEN
# 1049         Harding Pike & Woodmont Blvd  HARKENEN
# 1050  White Bridge Pike & Charlotte Shone  WHICORSF
#
#                              toStopName  pathLengthMeters  \
# 0        Hwy 70 S & Old Hickory Blvd Eb            24.305
# 1          West End Ave & 31st Ave S Eb            24.265
# 2                Hwy 70 S & Hicks Ln Eb            24.285
# 3          West End Ave & Kenner Ave Eb            24.853
# 4       West End Ave & Elmington Ave Eb            24.572
# ...                                 ...               ...
# 1046       Harding Pike & Harding Pl Eb            24.744
# 1047     West End Ave  & Leonard Ave Eb            23.956
# 1048             West End & Wilson Blvd            23.901
# 1049       West End Ave & Kenner Ave Eb            23.943
# 1050  White Bridge Pike & Corbett Ln Sb            24.651
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                 1.523679           15.951523    1.992          1.712  ...
# 1                 2.450000            9.904082    5.727          3.591  ...
# 2                 1.525286           15.921604    1.911          1.742  ...
# 3                 1.858706           13.371130    5.059          2.379  ...
# 4                 2.262116           10.862396   17.841          2.952  ...
# ...                    ...                 ...      ...            ...  ...
# 1046              1.349964           18.329378    1.648          1.545  ...
# 1047              1.505448           15.912871    1.995          1.743  ...
# 1048              1.515908           15.766788    2.007          1.745  ...
# 1049              2.396655            9.990174    4.176          3.647  ...
# 1050              2.960559            8.326468    6.263          4.813  ...
#
#       percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0             1.324    1.281               28          1.401  4/27/22-5/25/22
# 1             1.797    1.541               71          1.873  4/27/22-5/25/22
# 2             1.310    1.177               28          1.355  4/27/22-5/25/22
# 3             1.382    1.154               51          1.513  4/27/22-5/25/22
# 4             1.414    0.800               86          1.524  4/27/22-5/25/22
# ...             ...      ...              ...            ...              ...
# 1046          1.163    1.079               28          1.230  4/27/22-5/25/22
# 1047          1.255    1.090               87          1.348  4/27/22-5/25/22
# 1048          1.272    1.077               87          1.368  4/27/22-5/25/22
# 1049          1.683    1.396               29          1.963  4/27/22-5/25/22
# 1050          1.574    1.287               59          1.694  4/27/22-5/25/22
#
#          time  days_of_week  direction max_seg_count proportion_of_segments
# 0     6am-9am           m-f    inbound            89               0.314607
# 1     6am-9am           m-f    inbound            89               0.797753
# 2     6am-9am           m-f    inbound            89               0.314607
# 3     6am-9am           m-f    inbound            89               0.573034
# 4     6am-9am           m-f    inbound            89               0.966292
# ...       ...           ...        ...           ...                    ...
# 1046  6am-9am           m-f    inbound            89               0.314607
# 1047  6am-9am           m-f    inbound            89               0.977528
# 1048  6am-9am           m-f    inbound            89               0.977528
# 1049  6am-9am           m-f    inbound            89               0.325843
# 1050  6am-9am           m-f    inbound            89               0.662921
#
# [1051 rows x 24 columns]

# %%
martoapr = mfam_martoapr[mfam_martoapr['percent20Secs'] > np.quantile(mfam_martoapr['percent20Secs'], .80)]

# %%
params4a = {
    'direction': '1',
    'startDate': '04-27-2022',
    'beginTime' : '04:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '05-25-2022',
    'endTime' : '06:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
}


params4b = {
    'direction': '1',
    'startDate': '04-27-2022',
    'beginTime' : '04:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '05-25-2022',
    'endTime' : '06:00',
    'resolution': 'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_aprtomay = concat_frames_columns(requests.get(URL, params = params4a, headers = headers), 
                                      requests.get(URL, params = params4b, headers = headers), "4/27/22-5/25/22")
mfam_aprtomay
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.92385 36.07396, -86.92358 36.0...   H70HICEN
# 1     LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 2     LINESTRING (-86.93141 36.07377, -86.93114 36.0...   H70COLEM
# 3     LINESTRING (-86.85175 36.12782, -86.85153 36.1...   WHIPOSSN
# 4     LINESTRING (-86.82550 36.13446, -86.82525 36.1...   WESLEOEN
# ...                                                 ...        ...
# 1045  LINESTRING (-86.83046 36.13264, -86.83022 36.1...   WESWILEN
# 1046  LINESTRING (-86.83714 36.13047, -86.83689 36.1...   HARVINEN
# 1047  LINESTRING (-86.87775 36.09626, -86.87751 36.0...   H70PEREN
# 1048  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
# 1049  LINESTRING (-86.84734 36.12513, -86.84714 36.1...   HARWODEN
#
#                              fromStopName  toStopId  \
# 0                  Hwy 70 S & Hicks Ln Eb  H70OLDEF
# 1        West End Ave & Acklen Park Dr Eb  WES31AEM
# 2          Hwy 70 S & Colice Jeanne Rd Eb  H70HICEN
# 3          White Bridge Pike & Post Rd Sb  HARKENEN
# 4          West End Ave  & Leonard Ave Eb  WESELMEN
# ...                                   ...       ...
# 1045               West End & Wilson Blvd  WESLEOEN
# 1046            Harding Pike & Vine Ct Eb  WESWILEN
# 1047      Hwy 70 S & Percy Warner Blvd Eb  HARHAREN
# 1048  White Bridge Pike & Charlotte Shone  WHICORSF
# 1049         Harding Pike & Woodmont Blvd  HARKENEN
#
#                              toStopName  pathLengthMeters  \
# 0        Hwy 70 S & Old Hickory Blvd Eb            24.305
# 1          West End Ave & 31st Ave S Eb            24.265
# 2                Hwy 70 S & Hicks Ln Eb            24.285
# 3          West End Ave & Kenner Ave Eb            24.853
# 4       West End Ave & Elmington Ave Eb            24.572
# ...                                 ...               ...
# 1045     West End Ave  & Leonard Ave Eb            23.956
# 1046             West End & Wilson Blvd            23.901
# 1047       Harding Pike & Harding Pl Eb            24.744
# 1048  White Bridge Pike & Corbett Ln Sb            24.651
# 1049       West End Ave & Kenner Ave Eb            23.943
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                 1.511150           16.083777    1.853          1.742  ...
# 1                 2.301500           10.543124    4.985          2.979  ...
# 2                 1.424658           17.046196    1.771          1.686  ...
# 3                 1.662684           14.947519    4.675          1.972  ...
# 4                 3.266250            7.523000   33.639          5.344  ...
# ...                    ...                 ...      ...            ...  ...
# 1045              1.497845           15.993644    2.498          1.804  ...
# 1046              1.488196           16.060385    2.451          1.728  ...
# 1047              1.250769           19.783029    1.592          1.437  ...
# 1048              2.968638            8.303808    6.640          5.758  ...
# 1049              2.494538            9.598170    4.926          3.732  ...
#
#       percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0             1.310    0.911               40          1.356  4/27/22-5/25/22
# 1             1.719    1.359               84          1.818  4/27/22-5/25/22
# 2             1.188    0.922               38          1.264  4/27/22-5/25/22
# 3             1.306    1.136               57          1.386  4/27/22-5/25/22
# 4             1.420    1.248               96          1.528  4/27/22-5/25/22
# ...             ...      ...              ...            ...              ...
# 1045          1.263    1.111               97          1.329  4/27/22-5/25/22
# 1046          1.224    1.044               97          1.320  4/27/22-5/25/22
# 1047          1.084    0.955               39          1.112  4/27/22-5/25/22
# 1048          1.523    1.263               58          1.627  4/27/22-5/25/22
# 1049          1.729    1.406               39          1.894  4/27/22-5/25/22
#
#          time  days_of_week  direction max_seg_count proportion_of_segments
# 0     6am-9am           m-f    inbound            99               0.404040
# 1     6am-9am           m-f    inbound            99               0.848485
# 2     6am-9am           m-f    inbound            99               0.383838
# 3     6am-9am           m-f    inbound            99               0.575758
# 4     6am-9am           m-f    inbound            99               0.969697
# ...       ...           ...        ...           ...                    ...
# 1045  6am-9am           m-f    inbound            99               0.979798
# 1046  6am-9am           m-f    inbound            99               0.979798
# 1047  6am-9am           m-f    inbound            99               0.393939
# 1048  6am-9am           m-f    inbound            99               0.585859
# 1049  6am-9am           m-f    inbound            99               0.393939
#
# [1050 rows x 24 columns]

# %%
aprtomay = mfam_aprtomay[mfam_aprtomay['percent20Secs'] > np.quantile(mfam_aprtomay['percent20Secs'], .80)]

# %% [markdown]
# ## Summer Months

# %%
params5a = {
    'direction':'1',
    'startDate':'05-26-2022',
    'endDate': '06-25-2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params5b = {
    'direction':'1',
    'startDate':'05-26-2022',
    'endDate': '06-25-2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_maytojun = concat_frames_columns(requests.get(URL, params = params5a, headers = headers), 
                                      requests.get(URL, params = params5b, headers = headers), "4/27/22-5/25/22")
mfam_maytojun
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.92385 36.07396, -86.92358 36.0...   H70HICEN
# 1     LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 2     LINESTRING (-86.93141 36.07377, -86.93114 36.0...   H70COLEM
# 3     LINESTRING (-86.85175 36.12782, -86.85153 36.1...   WHIPOSSN
# 4     LINESTRING (-86.82550 36.13446, -86.82525 36.1...   WESLEOEN
# ...                                                 ...        ...
# 1045  LINESTRING (-86.87775 36.09626, -86.87751 36.0...   H70PEREN
# 1046  LINESTRING (-86.83046 36.13264, -86.83022 36.1...   WESWILEN
# 1047  LINESTRING (-86.83714 36.13047, -86.83689 36.1...   HARVINEN
# 1048  LINESTRING (-86.84734 36.12513, -86.84714 36.1...   HARWODEN
# 1049  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
#
#                              fromStopName  toStopId  \
# 0                  Hwy 70 S & Hicks Ln Eb  H70OLDEF
# 1        West End Ave & Acklen Park Dr Eb  WES31AEM
# 2          Hwy 70 S & Colice Jeanne Rd Eb  H70HICEN
# 3          White Bridge Pike & Post Rd Sb  HARKENEN
# 4          West End Ave  & Leonard Ave Eb  WESELMEN
# ...                                   ...       ...
# 1045      Hwy 70 S & Percy Warner Blvd Eb  HARHAREN
# 1046               West End & Wilson Blvd  WESLEOEN
# 1047            Harding Pike & Vine Ct Eb  WESWILEN
# 1048         Harding Pike & Woodmont Blvd  HARKENEN
# 1049  White Bridge Pike & Charlotte Shone  WHICORSF
#
#                              toStopName  pathLengthMeters  \
# 0        Hwy 70 S & Old Hickory Blvd Eb            24.305
# 1          West End Ave & 31st Ave S Eb            24.265
# 2                Hwy 70 S & Hicks Ln Eb            24.285
# 3          West End Ave & Kenner Ave Eb            24.853
# 4       West End Ave & Elmington Ave Eb            24.572
# ...                                 ...               ...
# 1045       Harding Pike & Harding Pl Eb            24.744
# 1046     West End Ave  & Leonard Ave Eb            23.956
# 1047             West End & Wilson Blvd            23.901
# 1048       West End Ave & Kenner Ave Eb            23.943
# 1049  White Bridge Pike & Corbett Ln Sb            24.651
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                 1.566024           15.520196    3.271          1.868  ...
# 1                 2.263644           10.719442    4.741          3.345  ...
# 2                 1.507300           16.111590    1.958          1.750  ...
# 3                 1.666143           14.916487    3.391          2.068  ...
# 4                 5.979692            4.109242   61.631         18.443  ...
# ...                    ...                 ...      ...            ...  ...
# 1045              1.277714           19.365836    1.708          1.572  ...
# 1046              1.577283           15.188143    2.660          1.918  ...
# 1047              1.534217           15.578631    2.851          1.848  ...
# 1048              2.700119            8.867387    5.139          4.612  ...
# 1049              3.158714            7.804125    6.639          5.348  ...
#
#       percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0             1.213    0.691               41          1.344  4/27/22-5/25/22
# 1             1.652    1.390               90          1.827  4/27/22-5/25/22
# 2             1.290    1.277               40          1.340  4/27/22-5/25/22
# 3             1.271    1.132               63          1.315  4/27/22-5/25/22
# 4             1.561    1.126              104          1.650  4/27/22-5/25/22
# ...             ...      ...              ...            ...              ...
# 1045          1.003    0.885               42          1.104  4/27/22-5/25/22
# 1046          1.242    1.074              106          1.352  4/27/22-5/25/22
# 1047          1.239    1.121              106          1.291  4/27/22-5/25/22
# 1048          1.631    1.536               42          1.797  4/27/22-5/25/22
# 1049          1.679    1.058               70          1.757  4/27/22-5/25/22
#
#          time  days_of_week  direction max_seg_count proportion_of_segments
# 0     6am-9am           m-f    inbound           106               0.386792
# 1     6am-9am           m-f    inbound           106               0.849057
# 2     6am-9am           m-f    inbound           106               0.377358
# 3     6am-9am           m-f    inbound           106               0.594340
# 4     6am-9am           m-f    inbound           106               0.981132
# ...       ...           ...        ...           ...                    ...
# 1045  6am-9am           m-f    inbound           106               0.396226
# 1046  6am-9am           m-f    inbound           106               1.000000
# 1047  6am-9am           m-f    inbound           106               1.000000
# 1048  6am-9am           m-f    inbound           106               0.396226
# 1049  6am-9am           m-f    inbound           106               0.660377
#
# [1050 rows x 24 columns]

# %%
maytojun = mfam_maytojun[mfam_maytojun['percent20Secs'] > np.quantile(mfam_maytojun['percent20Secs'], .80)]

# %%
params6a = {
    'direction':'1',
    'startDate':'06-26-2022',
    'endDate': '07-26-2022',
    'excludeDate': '07/04/2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}


params6b = {
    'direction':'1',
    'startDate':'06-26-2022',
    'endDate': '07-26-2022',
    'excludeDate': '07/04/2022',
    'beginTime': '04:00',
    'endTime': '06:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
mfam_juntojul = concat_frames_columns(requests.get(URL, params = params6a, headers = headers), 
                                      requests.get(URL, params = params6b, headers = headers), "4/27/22-5/25/22")
mfam_juntojul
# Out:
#                                                geometry fromStopId  \
# 0     LINESTRING (-86.92385 36.07396, -86.92358 36.0...   H70HICEN
# 1     LINESTRING (-86.81722 36.14104, -86.81704 36.1...   WESACKEN
# 2     LINESTRING (-86.93141 36.07377, -86.93114 36.0...   H70COLEM
# 3     LINESTRING (-86.85175 36.12782, -86.85153 36.1...   WHIPOSSN
# 4     LINESTRING (-86.82550 36.13446, -86.82525 36.1...   WESLEOEN
# ...                                                 ...        ...
# 1046  LINESTRING (-86.87775 36.09626, -86.87751 36.0...   H70PEREN
# 1047  LINESTRING (-86.83046 36.13264, -86.83022 36.1...   WESWILEN
# 1048  LINESTRING (-86.83714 36.13047, -86.83689 36.1...   HARVINEN
# 1049  LINESTRING (-86.84734 36.12513, -86.84714 36.1...   HARWODEN
# 1050  LINESTRING (-86.85794 36.14930, -86.85794 36.1...   WHICHASF
#
#                              fromStopName  toStopId  \
# 0                  Hwy 70 S & Hicks Ln Eb  H70OLDEF
# 1        West End Ave & Acklen Park Dr Eb  WES31AEM
# 2          Hwy 70 S & Colice Jeanne Rd Eb  H70HICEN
# 3          White Bridge Pike & Post Rd Sb  HARKENEN
# 4          West End Ave  & Leonard Ave Eb  WESELMEN
# ...                                   ...       ...
# 1046      Hwy 70 S & Percy Warner Blvd Eb  HARHAREN
# 1047               West End & Wilson Blvd  WESLEOEN
# 1048            Harding Pike & Vine Ct Eb  WESWILEN
# 1049         Harding Pike & Woodmont Blvd  HARKENEN
# 1050  White Bridge Pike & Charlotte Shone  WHICORSF
#
#                              toStopName  pathLengthMeters  \
# 0        Hwy 70 S & Old Hickory Blvd Eb            24.305
# 1          West End Ave & 31st Ave S Eb            24.265
# 2                Hwy 70 S & Hicks Ln Eb            24.285
# 3          West End Ave & Kenner Ave Eb            24.853
# 4       West End Ave & Elmington Ave Eb            24.572
# ...                                 ...               ...
# 1046       Harding Pike & Harding Pl Eb            24.744
# 1047     West End Ave  & Leonard Ave Eb            23.956
# 1048             West End & Wilson Blvd            23.901
# 1049       West End Ave & Kenner Ave Eb            23.943
# 1050  White Bridge Pike & Corbett Ln Sb            24.651
#
#       averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  ...  \
# 0                 1.559350           15.586623    2.831          1.912  ...
# 1                 2.098621           11.562355    7.711          2.802  ...
# 2                 1.426649           17.022407    1.747          1.620  ...
# 3                 1.770100           14.040450    5.836          2.131  ...
# 4                 2.914719            8.430315   30.261          4.302  ...
# ...                    ...                 ...      ...            ...  ...
# 1046              1.253711           19.736606    1.591          1.487  ...
# 1047              1.496551           16.007473    4.510          1.703  ...
# 1048              1.429455           16.720358    1.805          1.649  ...
# 1049              2.107921           11.358585    4.096          2.992  ...
# 1050              2.741778            8.990881    6.213          4.628  ...
#
#       percent10Secs  minSecs  countForSegment  percent20Secs            dates  \
# 0             1.236    1.115               40          1.318  4/27/22-5/25/22
# 1             1.519    1.251               87          1.614  4/27/22-5/25/22
# 2             1.195    1.047               37          1.296  4/27/22-5/25/22
# 3             1.369    1.045               60          1.431  4/27/22-5/25/22
# 4             1.322    1.115               96          1.397  4/27/22-5/25/22
# ...             ...      ...              ...            ...              ...
# 1046          0.969    0.727               38          1.136  4/27/22-5/25/22
# 1047          1.213    0.982               98          1.325  4/27/22-5/25/22
# 1048          1.217    1.069               99          1.286  4/27/22-5/25/22
# 1049          1.432    0.927               38          1.558  4/27/22-5/25/22
# 1050          1.593    1.407               63          1.695  4/27/22-5/25/22
#
#          time  days_of_week  direction max_seg_count proportion_of_segments
# 0     6am-9am           m-f    inbound            99               0.404040
# 1     6am-9am           m-f    inbound            99               0.878788
# 2     6am-9am           m-f    inbound            99               0.373737
# 3     6am-9am           m-f    inbound            99               0.606061
# 4     6am-9am           m-f    inbound            99               0.969697
# ...       ...           ...        ...           ...                    ...
# 1046  6am-9am           m-f    inbound            99               0.383838
# 1047  6am-9am           m-f    inbound            99               0.989899
# 1048  6am-9am           m-f    inbound            99               1.000000
# 1049  6am-9am           m-f    inbound            99               0.383838
# 1050  6am-9am           m-f    inbound            99               0.636364
#
# [1051 rows x 24 columns]

# %%
juntojul = mfam_juntojul[mfam_juntojul['percent20Secs'] > np.quantile(mfam_juntojul['percent20Secs'], .80)]

# %%
r3oimschool = pd.concat([jantofeb, febtomar, martoapr,aprtomay], keys=['jantofeb','febtomar','martoapr','aprtomay'])
r3oimsummer = pd.concat([maytojun, juntojul], keys=['maytojun', 'juntojul'])
r3oimschool_gj = r3oimschool['geometry'].to_json()
r3oimsummer_gj = r3oimsummer['geometry'].to_json()
mapdawg = folium.Map(location = [36.19, -86.7775], zoom_start = 12)

# %%
style1 = {'color' : 'red', 'weight' : 6}
style2 = {'color' : 'blue', 'weight' : 3}
folium.GeoJson(r3oimschool_gj, style_function =lambda x:style1).add_to(mapdawg)
folium.GeoJson(r3oimsummer_gj, style_function = lambda x:style2).add_to(mapdawg)
mapdawg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b053c082141955714290d9c21cb67e52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b053c082141955714290d9c21cb67e52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b053c082141955714290d9c21cb67e52 = L.map(
#                 &quot;map_b053c082141955714290d9c21cb67e52&quot;,
#                 {
#                     center: [36.19, -86.7775],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8ea4417fbe88e83149b4ded9d3e9613 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b053c082141955714290d9c21cb67e52);
#
#
#         function geo_json_80152c4fdc6fbd1eebe768080a8d35da_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;weight&quot;: 6};
#             }
#         }
#         function geo_json_80152c4fdc6fbd1eebe768080a8d35da_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_b053c082141955714290d9c21cb67e52.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_80152c4fdc6fbd1eebe768080a8d35da = L.geoJson(null, {
#                 onEachFeature: geo_json_80152c4fdc6fbd1eebe768080a8d35da_onEachFeature,
#
#                 style: geo_json_80152c4fdc6fbd1eebe768080a8d35da_styler,
#         }).addTo(map_b053c082141955714290d9c21cb67e52);
#
#         function geo_json_80152c4fdc6fbd1eebe768080a8d35da_add (data) {
#             geo_json_80152c4fdc6fbd1eebe768080a8d35da.addData(data);
#         }
#             geo_json_80152c4fdc6fbd1eebe768080a8d35da_add({&quot;bbox&quot;: [-86.95652569442052, 36.06877007296196, -86.7811952078171, 36.166452036677725], &quot;features&quot;: [{&quot;bbox&quot;: [-86.79423618134263, 36.15381690932869, -86.79398948770094, 36.15391350409969], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.79423618134263, 36.15381690932869], [-86.79398948770094, 36.15391350409969]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 11)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78372914832912, 36.165036514168456, -86.78349553110549, 36.1651353522246], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78372914832912, 36.165036514168456], [-86.78349553110549, 36.1651353522246]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 12)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.81425543957356, 36.14358102378774, -86.81406725276474, 36.143738031716985], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.81425543957356, 36.14358102378774], [-86.81406725276474, 36.143738031716985]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 18)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78396276555274, 36.1649376761123, -86.78372914832912, 36.165036514168456], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78396276555274, 36.1649376761123], [-86.78372914832912, 36.165036514168456]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 27)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.79398948770094, 36.15391350409969, -86.79373527845631, 36.15399824051456], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.79398948770094, 36.15391350409969], [-86.79373527845631, 36.15399824051456]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 31)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78467356100748, 36.16463814721506, -86.78443584317608, 36.16473755649], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78467356100748, 36.16463814721506], [-86.78443584317608, 36.16473755649]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 44)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.78326191388186, 36.165234190280756, -86.78302829665823, 36.1653330283369], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78326191388186, 36.165234190280756], [-86.78302829665823, 36.1653330283369]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(\u0027jantofeb\u0027, 46)&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-86.784620435617, 36.16266207813985, -86.78449182203343, 36.16286067264389], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-86.78449182203343, 36.16266207813985], [-86.784620435617, 36.16286067264389]], &quot;type&quot;: &quot;LineString&quot;}, &quo
