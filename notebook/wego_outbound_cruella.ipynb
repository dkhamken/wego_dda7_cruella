# %% [markdown]
# ## Route 3 West End - Outbound 6-9AM

# %%
import geopandas as gpd 
import requests 
import pandas as pd
import matplotlib.pyplot as plt 
import json
from shapely.geometry import LineString


# %matplotlib inline

# %%
with open('../data/WeGo.json')as start:
         credentials = json.load(start)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/3'

# %% [markdown]
# ## 1/25-5/24 M/onday-Friday 06:00-09:00 AM PEAK

# %%
params_geo = {
    'direction':'0',
    'startDate':'01-25-2022',
    'endDate': '02-24-2022',
    'excludeDates': '02-18-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}
response_geo = requests.get(URL, params = params_geo, headers=headers)
response_line_segments = response_geo.json()['features']
route3_125mf_gdf = gpd.GeoDataFrame.from_features(response_line_segments)
route3_125mf_gdf
# Out:
#                                               geometry fromStopId  \
# 0    LINESTRING (-86.78639 36.15708, -86.78663 36.1...    BRO9AWF
# 1    LINESTRING (-86.81879 36.13973, -86.81897 36.1...   WESACKWN
# 2    LINESTRING (-86.82326 36.13553, -86.82348 36.1...   WES440WN
# 3    LINESTRING (-86.81680 36.14151, -86.81698 36.1...   WES31AWN
# 4    LINESTRING (-86.85538 36.13003, -86.85560 36.1...     WBBTNF
# ..                                                 ...        ...
# 509  LINESTRING (-86.85766 36.13797, -86.85761 36.1...   WHIKNONN
# 510  LINESTRING (-86.81570 36.14246, -86.81588 36.1...   WES31AWN
# 511  LINESTRING (-86.85427 36.12938, -86.85450 36.1...   WHIPOSNN
# 512  LINESTRING (-86.84662 36.12575, -86.84682 36.1...   HARBOSWM
# 513  LINESTRING (-86.85804 36.14839, -86.85830 36.1...   WHIBURNN
#
#                             fromStopName  toStopId  \
# 0            Broadway Ave & 9th Ave S Wb   BRO12WN
# 1       West End Ave & Acklen Park Dr Wb  WES440WN
# 2           West End Ave & I-440 Ramp Wb  WESBOWWN
# 3           West End Ave & 31st Ave N Wb  WESACKWN
# 4    White Bridge Rd & Brookwood Terrace  WHIBRONF
# ..                                   ...       ...
# 509       White Bridge Pike & Knob Rd Nb  WHIKENNN
# 510         West End Ave & 31st Ave N Wb  WESACKWN
# 511       White Bridge Pike & Post Rd Nb    WBBTNF
# 512  Harding Pike & Bosley Springs Rd Wb  WHIPOSNN
# 513   White Bridge Pike & Burgess Ave Nb  CXIWTBRG
#
#                               toStopName  pathLengthMeters  \
# 0           Broadway Ave & 12th Ave N Wb            24.288
# 1           West End Ave & I-440 Ramp Wb            24.223
# 2          West End Ave & Bowling Ave Wb            24.868
# 3       West End Ave & Acklen Park Dr Wb            24.188
# 4    White Bridge Pike & Brookwood Pl Nb            24.347
# ..                                   ...               ...
# 509    White Bridge Pike & Kendall Dr Nb            24.392
# 510     West End Ave & Acklen Park Dr Wb            24.188
# 511  White Bridge Rd & Brookwood Terrace            24.702
# 512       White Bridge Pike & Post Rd Nb            24.628
# 513         White Bridge Station Inbound            24.360
#
#      averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0                2.882960            8.424675    7.505          4.430
# 1                4.441792            5.453430   61.962          6.958
# 2                4.057221            6.129319   36.018          8.277
# 3                3.479817            6.950940   34.526          5.659
# 4                1.758763           13.843252    4.348          2.241
# ..                    ...                 ...      ...            ...
# 509              2.730623            8.932760    6.282          4.988
# 510              2.610033            9.267316    5.223          4.135
# 511              2.670081            9.251405   34.313          4.215
# 512              2.777198            8.867931   17.843          3.821
# 513              2.963762            8.219283    8.114          4.837
#
#      percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0            3.741          3.327      2.4860          2.077          1.743
# 1            3.692          2.709      2.1545          1.895          1.562
# 2            4.315          3.423      2.5340          1.966          1.671
# 3            4.216          3.303      2.2980          1.844          1.648
# 4            1.933          1.802      1.6120          1.493          1.355
# ..             ...            ...         ...            ...            ...
# 509          3.786          2.927      2.3080          1.911          1.613
# 510          3.447          2.953      2.2860          1.952          1.714
# 511          2.292          1.974      1.7080          1.552          1.380
# 512          2.972          2.754      2.3510          2.095          1.882
# 513          3.966          3.553      2.8270          2.472          0.632
#
#      minSecs
# 0      1.404
# 1      1.199
# 2      1.117
# 3      1.197
# 4      1.098
# ..       ...
# 509    1.120
# 510    1.304
# 511    1.114
# 512    1.582
# 513    0.482
#
# [514 rows x 16 columns]

# %%
params = {
    'direction':'0',
    'startDate':'01-25-2022',
    'endDate': '02-24-2022',
    'excludeDates': '02-18-2022',
    'beginTime': '06:00',
    'endTime': '09:00',
    'daysOfWeek': '1,2,3,4,5',
    #'format':'geojson',
    'resolution':'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}
response = requests.get(URL, params = params, headers=headers)
response_line_segments = response.json()['data']['segments']
route3_125mf_df = pd.DataFrame.from_dict(response_line_segments)
route3_125mf_df
# Out:
#                                               pathLocs  maxSecs  \
# 0    [{'lat': 36.1570752765724, 'lon': -86.78639021...    7.505
# 1    [{'lat': 36.13973499753115, 'lon': -86.8187941...   61.962
# 2    [{'lat': 36.135528484884816, 'lon': -86.823255...   36.018
# 3    [{'lat': 36.14150705171058, 'lon': -86.8167993...   34.526
# 4    [{'lat': 36.13002620841803, 'lon': -86.8553797...    4.348
# ..                                                 ...      ...
# 509  [{'lat': 36.13796992938271, 'lon': -86.8576617...    6.282
# 510  [{'lat': 36.142461762927645, 'lon': -86.815697...    5.223
# 511  [{'lat': 36.12938073593112, 'lon': -86.8542726...   34.313
# 512  [{'lat': 36.12574913166674, 'lon': -86.8466153...   17.843
# 513  [{'lat': 36.1483948521199, 'lon': -86.85803794...    8.114
#
#      percent90Secs  percent80Secs  percent70Secs  medianSecs  percent30Secs  \
# 0            4.430          3.741          3.327      2.4860          2.077
# 1            6.958          3.692          2.709      2.1545          1.895
# 2            8.277          4.315          3.423      2.5340          1.966
# 3            5.659          4.216          3.303      2.2980          1.844
# 4            2.241          1.933          1.802      1.6120          1.493
# ..             ...            ...            ...         ...            ...
# 509          4.988          3.786          2.927      2.3080          1.911
# 510          4.135          3.447          2.953      2.2860          1.952
# 511          4.215          2.292          1.974      1.7080          1.552
# 512          3.821          2.972          2.754      2.3510          2.095
# 513          4.837          3.966          3.553      2.8270          2.472
#
#      percent20Secs  percent10Secs  minSecs  pathLengthMeters  \
# 0            1.928          1.743    1.404            24.288
# 1            1.772          1.562    1.199            24.223
# 2            1.826          1.671    1.117            24.868
# 3            1.745          1.648    1.197            24.188
# 4            1.436          1.355    1.098            24.347
# ..             ...            ...      ...               ...
# 509          1.745          1.613    1.120            24.392
# 510          1.815          1.714    1.304            24.188
# 511          1.481          1.380    1.114            24.702
# 512          2.005          1.882    1.582            24.628
# 513          2.258          0.632    0.482            24.360
#
#      averageTravelSeconds  averageTravelSpeed  \
# 0                2.882960            8.424675
# 1                4.441792            5.453430
# 2                4.057221            6.129319
# 3                3.479817            6.950940
# 4                1.758763           13.843252
# ..                    ...                 ...
# 509              2.730623            8.932760
# 510              2.610033            9.267316
# 511              2.670081            9.251405
# 512              2.777198            8.867931
# 513              2.963762            8.219283
#
#                                                 toStop  \
# 0    {'configRev': 49, 'stopPathId': 'BRO9AWF_to_BR...
# 1    {'configRev': 49, 'stopPathId': 'WESACKWN_to_W...
# 2    {'configRev': 49, 'stopPathId': 'WES440WN_to_W...
# 3    {'configRev': 49, 'stopPathId': 'WES31AWN_to_W...
# 4    {'configRev': 49, 'stopPathId': 'WBBTNF_to_WHI...
# ..                                                 ...
# 509  {'configRev': 49, 'stopPathId': 'WHIKNONN_to_W...
# 510  {'configRev': 49, 'stopPathId': 'WES31AWN_to_W...
# 511  {'configRev': 49, 'stopPathId': 'WHIPOSNN_to_W...
# 512  {'configRev': 49, 'stopPathId': 'HARBOSWM_to_W...
# 513  {'configRev': 49, 'stopPathId': 'WHIBURNN_to_C...
#
#                                               fromStop  countForSegment
# 0    {'configRev': 49, 'stopPathId': '8ABROSN_to_BR...              173
# 1    {'configRev': 49, 'stopPathId': 'WES31AWN_to_W...              154
# 2    {'configRev': 49, 'stopPathId': 'WESACKWN_to_W...              154
# 3    {'configRev': 49, 'stopPathId': 'WES27AWN_to_W...              153
# 4    {'configRev': 49, 'stopPathId': 'WHIPOSNN_to_W...              173
# ..                                                 ...              ...
# 509  {'configRev': 49, 'stopPathId': 'WHISTONF_to_W...              146
# 510  {'configRev': 49, 'stopPathId': 'WES27AWN_to_W...              153
# 511  {'configRev': 49, 'stopPathId': 'HARBOSWM_to_W...              172
# 512  {'configRev': 49, 'stopPathId': 'HARBOSWN_to_H...              172
# 513  {'configRev': 49, 'stopPathId': 'WHICORNN_to_W...              143
#
# [514 rows x 16 columns]
